# %%
import matplotlib.pyplot as plt
#data manipulations
import numpy as np
import pandas as pd
#pytorch
import torchvision
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as f
#scraping from internet
from PIL import Image
#scraping from internet
import requests
from io import BytesIO
# time related
from timeit import default_timer as timer

# %%
# transforms for images
transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize(256),
    torchvision.transforms.CenterCrop(224),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.RandomHorizontalFlip(p = 0.5)
])


# datasets
trainset = torchvision.datasets.ImageFolder("../input/modified-dataset/train", transform = transforms)
validset = torchvision.datasets.ImageFolder("../input/modified-dataset/val", transform = transforms)
testset = torchvision.datasets.ImageFolder("../input/modified-dataset/test", transform = transforms)

#batches
batch_size = 128

# loaders for data
trainloader = torch.utils.data.DataLoader(trainset , batch_size=batch_size , shuffle = True)
validloader = torch.utils.data.DataLoader(validset , batch_size=batch_size , shuffle = True)
testloader = torch.utils.data.DataLoader(testset  , batch_size=batch_size)

# %%
images, labels = iter(trainloader).next()
images, labels = images.numpy() , labels.numpy()

fig = plt.figure(figsize = (15,5))

for i in range(int(batch_size/8)):
    ax = fig.add_subplot(2 , int(batch_size/16) , i + 1 , xticks = [] , yticks = [])
    ax.imshow(np.transpose(images[i] , (1,2,0)) , cmap = 'gray')
    ax.set_title(trainset.classes[labels[i]])

# %%
# Single batch
print("number of train batches : ", len(trainloader))
print("number of validation batches : ", len(validloader))
print("Size of test batches : ", len(testloader))
# Out:
# number of train batches :  113
#
# number of validation batches :  16
#
# Size of test batches :  33

# %%
print("Unique classes number : ",len(trainset.classes))
print("Classes : ", trainset.classes)
# Out:
# Unique classes number :  120
#
# Classes :  ['Afghan_hound', 'African_hunting_dog', 'Airedale', 'American_Staffordshire_terrier', 'Appenzeller', 'Australian_terrier', 'Bedlington_terrier', 'Bernese_mountain_dog', 'Blenheim_spaniel', 'Border_collie', 'Border_terrier', 'Boston_bull', 'Bouvier_des_Flandres', 'Brabancon_griffon', 'Brittany_spaniel', 'Cardigan', 'Chesapeake_Bay_retriever', 'Chihuahua', 'Dandie_Dinmont', 'Doberman', 'English_foxhound', 'English_setter', 'English_springer', 'EntleBucher', 'Eskimo_dog', 'French_bulldog', 'German_shepherd', 'German_short-haired_pointer', 'Gordon_setter', 'Great_Dane', 'Great_Pyrenees', 'Greater_Swiss_Mountain_dog', 'Ibizan_hound', 'Irish_setter', 'Irish_terrier', 'Irish_water_spaniel', 'Irish_wolfhound', 'Italian_greyhound', 'Japanese_spaniel', 'Kerry_blue_terrier', 'Labrador_retriever', 'Lakeland_terrier', 'Leonberg', 'Lhasa', 'Maltese_dog', 'Mexican_hairless', 'Newfoundland', 'Norfolk_terrier', 'Norwegian_elkhound', 'Norwich_terrier', 'Old_English_sheepdog', 'Pekinese', 'Pembroke', 'Pomeranian', 'Rhodesian_ridgeback', 'Rottweiler', 'Saint_Bernard', 'Saluki', 'Samoyed', 'Scotch_terrier', 'Scottish_deerhound', 'Sealyham_terrier', 'Shetland_sheepdog', 'Shih-Tzu', 'Siberian_husky', 'Staffordshire_bullterrier', 'Sussex_spaniel', 'Tibetan_mastiff', 'Tibetan_terrier', 'Walker_hound', 'Weimaraner', 'Welsh_springer_spaniel', 'West_Highland_white_terrier', 'Yorkshire_terrier', 'affenpinscher', 'basenji', 'basset', 'beagle', 'black-and-tan_coonhound', 'bloodhound', 'bluetick', 'borzoi', 'boxer', 'briard', 'bull_mastiff', 'cairn', 'chow', 'clumber', 'cocker_spaniel', 'collie', 'curly-coated_retriever', 'dhole', 'dingo', 'flat-coated_retriever', 'giant_schnauzer', 'golden_retriever', 'groenendael', 'keeshond', 'kelpie', 'komondor', 'kuvasz', 'malamute', 'malinois', 'miniature_pinscher', 'miniature_poodle', 'miniature_schnauzer', 'otterhound', 'papillon', 'pug', 'redbone', 'schipperke', 'silky_terrier', 'soft-coated_wheaten_terrier', 'standard_poodle', 'standard_schnauzer', 'toy_poodle', 'toy_terrier', 'vizsla', 'whippet', 'wire-haired_fox_terrier']

# %%
# Whether to train on a gpu
my_gpu = torch.cuda.is_available()
print(f'Train on gpu: {my_gpu}')
device = torch.device('cuda' if my_gpu else 'cpu')
print(f"my device: {torch.cuda.get_device_name(0)}")
# Out:
# Train on gpu: True
#
# my device: Tesla T4

# %%
import torch.nn as nn

model = torchvision.models.mobilenet_v2(pretrained = False)  

#freeze model params

#for param in model.parameters():
#    param = param.requires_grad_(False)

#new layer
model.classifier[1] = torch.nn.Linear(in_features=model.classifier[1].in_features, out_features=len(trainset.classes))
print(model.classifier)
print(model.eval())


model = model.to(device) #Moving the model to GPU
# Out:
# Sequential(
#
#   (0): Dropout(p=0.2, inplace=False)
#
#   (1): Linear(in_features=1280, out_features=120, bias=True)
#
# )
#
# MobileNetV2(
#
#   (features): Sequential(
#
#     (0): ConvNormActivation(
#
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       (2): ReLU6(inplace=True)
#
#     )
#
#     (1): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (2): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (3): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (4): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (5): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (6): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (7): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (8): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (9): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (10): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (11): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (12): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (13): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (14): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (15): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (16): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (17): InvertedResidual(
#
#       (conv): Sequential(
#
#         (0): ConvNormActivation(
#
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (1): ConvNormActivation(
#
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#           (2): ReLU6(inplace=True)
#
#         )
#
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       )
#
#     )
#
#     (18): ConvNormActivation(
#
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
#       (2): ReLU6(inplace=True)
#
#     )
#
#   )
#
#   (classifier): Sequential(
#
#     (0): Dropout(p=0.2, inplace=False)
#
#     (1): Linear(in_features=1280, out_features=120, bias=True)
#
#   )
#
# )

# %%
lr = 1e-3
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters() , lr = lr)

# %%
#format class

class color_formats:
    """
    Simple color formating:
    Variables:
        >OKCYAN - cyan printing.
        >Bold - bold printing.
        >UNDERLINE - underline printing.
    """
    OKCYAN = '\033[96m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# %%
def train_loop(model,
          criterion,
          optimizer,
          train_loader,
          valid_loader,
          save_model_name,
          max_epochs_stop=100,
          num_epochs=100,
          num_epochs_report=1):
    """Train a neural network Model
    Args
    --------
        >model (Pytorch nn model): The neural network for the training process.  
        >criterion (Pytorch loss function): Initialize the loss function.
        >optimizer (Pytorch optimizer): Use an optimizer to compute gradients to update the weights.
        >train_loader (Pytorch dataloader): training dataloader to iterate through.
        >valid_loader (Pytorch dataloader): validation dataloader used for early stopping.
        >save_model_name (str): file path to save the model state dict, file name ends with 'pt.'.
        >max_epochs_stop (int): maximum number of epochs with no improvement in validation loss for early stopping.
        >num_epochs (int): maximum number of training epochs if the early stopping is not activated.
        >num_epochs_report (int): frequency of epochs to print training reports.
    
    outputs
    --------
        >model (PyTorch model): Trained neural networks with best weights.
        >history (DataFrame): History of train and validation loss and accuracy.
    """

    # Early stopping intialization
    epochs_no_improve = 0
    valid_loss_min = np.Inf  

    valid_max_acc = 0
    history = []

    # Number trained epochs  (while using loaded in model weights)
    try:
        print(f'Model has been trained for: {model.epochs} epochs.\n')
    except:
        model.epochs = 0
        print(f'{color_formats.BOLD + color_formats.UNDERLINE}Training activated:{color_formats.ENDC}\n')

    overall_start = timer()

    # Start of loop
    for epoch in range(num_epochs):

        # Track of training and validation loss for each epoch
        train_loss = 0.0
        valid_loss = 0.0

        train_acc = 0
        valid_acc = 0

        # Set model to train
        model.train()
        
        #start timer
        start = timer()

        # Training loop
        for ii, (data, target) in enumerate(train_loader):
            # Put the data in the gpu
            if my_gpu:
                data, target = data.to(device), target.to(device)

            # Remove past gradients
            optimizer.zero_grad()
            # Predicted outputs as log probabilities
            output = model(data)

            # Loss and backpropagation of gradients
            loss = criterion(output, target.long())
            loss.backward()

            # Update the weights
            optimizer.step()

            # Track train loss by multiplying average loss by number of examples in batch
            train_loss += loss.item() * data.size(0)

            # Calculate accuracy by finding max log probability
            _, pred = torch.max(output, dim=1)
            correct_tensor = pred.eq(target.data.view_as(pred))
            # Need to convert correct tensor from int to float to average
            accuracy = torch.mean(correct_tensor.type(torch.FloatTensor))
            # Multiply average accuracy times the number of examples in batch
            train_acc += accuracy.item() * data.size(0)

            # Training progress tracker
            print(
                f'Epoch: {epoch+1}\t{100 * (ii + 1) / len(train_loader):.2f}% complete. {timer() - start:.2f} seconds elapsed in epoch.',
                end='\r')


        # Start validation after training loops ends.
        else:
            model.epochs += 1

            # Deactivate the gradient tracking. 
            with torch.no_grad():
                # Set to evaluation mode
                model.eval()

                # Validation loop
                for data, target in valid_loader:
                    # Put the data in the gpu
                    if my_gpu:
                        data, target = data.to(device), target.to(device)

                    # Predicted outputs as log probabilities
                    output = model(data)

                    # Validation loss
                    loss = criterion(output, target.long())
                    # Multiply average loss times the number of examples in batch
                    valid_loss += loss.item() * data.size(0)

                    # Calculate accuracy of validation set
                    _, pred = torch.max(output, dim=1)
                    correct_tensor = pred.eq(target.data.view_as(pred))
                    accuracy = torch.mean(
                        correct_tensor.type(torch.FloatTensor))
                    # Multiply average accuracy times the number of examples
                    valid_acc += accuracy.item() * data.size(0)

                # Calculate average losses
                train_loss = train_loss / len(train_loader.dataset)
                valid_loss = valid_loss / len(valid_loader.dataset)

                # Calculate average accuracy
                train_acc = train_acc / len(train_loader.dataset)
                valid_acc = valid_acc / len(valid_loader.dataset)

                history.append([train_loss, valid_loss, train_acc, valid_acc])

                # Print training and validation results for the num_epochs_report that was set
                if (epoch + 1) % num_epochs_report == 0:
                    print(
                        f'\n\nEpoch: {color_formats.BOLD}{epoch+1}{color_formats.ENDC} \tTraining Loss: {color_formats.BOLD}{train_loss:.4f}{color_formats.ENDC} \tValidation Loss: {color_formats.BOLD}{valid_loss:.4f}{color_formats.ENDC}'
                    )
                    print(
                        f'\t\tTraining Accuracy: {color_formats.BOLD}{100 * train_acc:.2f}%{color_formats.ENDC}\t Validation Accuracy: {color_formats.BOLD}{100 * valid_acc:.2f}%{color_formats.ENDC}\n'
                    )

                # Save the model if validation loss decreases
                if valid_loss < valid_loss_min:
                    # Save model
                    torch.save(model.state_dict(), save_model_name)
                    # Track improvement
                    epochs_no_improve = 0
                    valid_loss_min = valid_loss
                    valid_best_acc = valid_acc
                    best_epoch = epoch + 1

                # Otherwise count all consecutive epochs with no improvement.
                else:
                    epochs_no_improve += 1
                    # Trigger early stopping
                    if epochs_no_improve >= max_epochs_stop:
                        print(
                            f'\n\n{color_formats.OKCYAN}Early stopping activated!{color_formats.ENDC}\nthe validation loss has not improved for {max_epochs_stop} epochs.\n\n{color_formats.BOLD + color_formats.UNDERLINE}End of training report:{color_formats.ENDC}\n\n\t-Total epochs: {epoch+1} \n\t-Best epoch: {color_formats.BOLD}{best_epoch}{color_formats.ENDC} \n\t-loss: {color_formats.BOLD}{valid_loss_min:.2f}{color_formats.ENDC} \n\t-accuracy: {color_formats.BOLD}{100 * valid_best_acc:.2f}%\n{color_formats.ENDC}'
                        )
                        total_time = timer() - overall_start
                        print(
                            f'{total_time:.2f} total seconds elapsed. {total_time / (epoch+1):.2f} seconds per epoch.'
                        )

                        # Load the best state dict
                        model.load_state_dict(torch.load(save_model_name))
                        # Attach the optimizer
                        model.optimizer = optimizer

                        # History update
                        history = pd.DataFrame(
                            history,
                            columns=[
                                'train_loss', 'valid_loss', 'train_acc',
                                'valid_acc'
                            ])
                        return model, history


    # Record overall time and print out Report
    total_time = timer() - overall_start
    print(
        f'\nBest epoch is epoch #{best_epoch} with loss: {valid_loss_min:.2f} and acc: {100 * valid_acc:.2f}%'
    )
    print(
        f'{total_time:.2f} total seconds elapsed. {total_time / (epoch):.2f} seconds per epoch.'
    )
    # History update
    history = pd.DataFrame(
        history,
        columns=['train_loss', 'valid_loss', 'train_acc', 'valid_acc'])
    return model, history

# %%
# Start Training
# Running the model
model, history = train_loop(
    model,
    criterion,
    optimizer,
    trainloader,
    validloader,
    save_model_name="./mobilenetv2_dog_scratch.pt",
    max_epochs_stop=100,
    num_epochs=100,
    num_epochs_report=1)
# Out:
# Training activated:
#
#
#
# Epoch: 1	100.00% complete. 305.31 seconds elapsed in epoch.
#
#
#
# Epoch: 1 	Training Loss: 4.7222 	Validation Loss: 4.6937
#
# 		Training Accuracy: 2.06%	 Validation Accuracy: 2.89%
#
#
#
# Epoch: 2	100.00% complete. 175.26 seconds elapsed in epoch.
#
#
#
# Epoch: 2 	Training Loss: 4.3287 	Validation Loss: 4.2673
#
# 		Training Accuracy: 4.82%	 Validation Accuracy: 5.28%
#
#
#
# Epoch: 3	100.00% complete. 172.64 seconds elapsed in epoch.
#
#
#
# Epoch: 3 	Training Loss: 4.1044 	Validation Loss: 4.2330
#
# 		Training Accuracy: 7.02%	 Validation Accuracy: 6.57%
#
#
#
# Epoch: 4	100.00% complete. 172.34 seconds elapsed in epoch.
#
#
#
# Epoch: 4 	Training Loss: 3.8933 	Validation Loss: 4.1372
#
# 		Training Accuracy: 9.53%	 Validation Accuracy: 6.92%
#
#
#
# Epoch: 5	100.00% complete. 171.58 seconds elapsed in epoch.
#
#
#
# Epoch: 5 	Training Loss: 3.7065 	Validation Loss: 3.8120
#
# 		Training Accuracy: 11.81%	 Validation Accuracy: 10.85%
#
#
#
# Epoch: 6	100.00% complete. 174.38 seconds elapsed in epoch.
#
#
#
# Epoch: 6 	Training Loss: 3.4804 	Validation Loss: 3.7649
#
# 		Training Accuracy: 15.24%	 Validation Accuracy: 13.29%
#
#
#
# Epoch: 7	100.00% complete. 171.18 seconds elapsed in epoch.
#
#
#
# Epoch: 7 	Training Loss: 3.2913 	Validation Loss: 3.6584
#
# 		Training Accuracy: 18.62%	 Validation Accuracy: 14.14%
#
#
#
# Epoch: 8	100.00% complete. 170.93 seconds elapsed in epoch.
#
#
#
# Epoch: 8 	Training Loss: 3.0761 	Validation Loss: 3.5412
#
# 		Training Accuracy: 21.81%	 Validation Accuracy: 15.98%
#
#
#
# Epoch: 9	100.00% complete. 170.97 seconds elapsed in epoch.
#
#
#
# Epoch: 9 	Training Loss: 2.8862 	Validation Loss: 3.6565
#
# 		Training Accuracy: 25.74%	 Validation Accuracy: 15.48%
#
#
#
# Epoch: 10	100.00% complete. 170.93 seconds elapsed in epoch.
#
#
#
# Epoch: 10 	Training Loss: 2.6782 	Validation Loss: 3.3362
#
# 		Training Accuracy: 29.91%	 Validation Accuracy: 19.81%
#
#
#
# Epoch: 11	100.00% complete. 169.52 seconds elapsed in epoch.
#
#
#
# Epoch: 11 	Training Loss: 2.4845 	Validation Loss: 3.1560
#
# 		Training Accuracy: 33.68%	 Validation Accuracy: 24.94%
#
#
#
# Epoch: 12	100.00% complete. 169.69 seconds elapsed in epoch.
#
#
#
# Epoch: 12 	Training Loss: 2.3194 	Validation Loss: 3.1762
#
# 		Training Accuracy: 37.03%	 Validation Accuracy: 24.59%
#
#
#
# Epoch: 13	100.00% complete. 172.19 seconds elapsed in epoch.
#
#
#
# Epoch: 13 	Training Loss: 2.1567 	Validation Loss: 3.0412
#
# 		Training Accuracy: 40.70%	 Validation Accuracy: 28.57%
#
#
#
# Epoch: 14	100.00% complete. 168.70 seconds elapsed in epoch.
#
#
#
# Epoch: 14 	Training Loss: 2.0235 	Validation Loss: 3.0780
#
# 		Training Accuracy: 43.56%	 Validation Accuracy: 28.67%
#
#
#
# Epoch: 15	100.00% complete. 169.87 seconds elapsed in epoch.
#
#
#
# Epoch: 15 	Training Loss: 1.8853 	Validation Loss: 2.9514
#
# 		Training Accuracy: 46.84%	 Validation Accuracy: 28.97%
#
#
#
# Epoch: 16	100.00% complete. 174.28 seconds elapsed in epoch.
#
#
#
# Epoch: 16 	Training Loss: 1.7344 	Validation Loss: 2.8493
#
# 		Training Accuracy: 50.83%	 Validation Accuracy: 30.91%
#
#
#
# Epoch: 17	100.00% complete. 170.10 seconds elapsed in epoch.
#
#
#
# Epoch: 17 	Training Loss: 1.6171 	Validation Loss: 2.9128
#
# 		Training Accuracy: 53.70%	 Validation Accuracy: 31.86%
#
#
#
# Epoch: 18	100.00% complete. 171.03 seconds elapsed in epoch.
#
#
#
# Epoch: 18 	Training Loss: 1.4976 	Validation Loss: 2.8116
#
# 		Training Accuracy: 56.88%	 Validation Accuracy: 32.06%
#
#
#
# Epoch: 19	100.00% complete. 171.43 seconds elapsed in epoch.
#
#
#
# Epoch: 19 	Training Loss: 1.3598 	Validation Loss: 2.9636
#
# 		Training Accuracy: 60.30%	 Validation Accuracy: 33.25%
#
#
#
# Epoch: 20	100.00% complete. 171.47 seconds elapsed in epoch.
#
#
#
# Epoch: 20 	Training Loss: 1.2238 	Validation Loss: 3.0946
#
# 		Training Accuracy: 64.16%	 Validation Accuracy: 32.16%
#
#
#
# Epoch: 21	100.00% complete. 169.57 seconds elapsed in epoch.
#
#
#
# Epoch: 21 	Training Loss: 1.1576 	Validation Loss: 3.1464
#
# 		Training Accuracy: 65.70%	 Validation Accuracy: 31.91%
#
#
#
# Epoch: 22	100.00% complete. 172.51 seconds elapsed in epoch.
#
#
#
# Epoch: 22 	Training Loss: 1.0658 	Validation Loss: 2.7575
#
# 		Training Accuracy: 67.99%	 Validation Accuracy: 34.00%
#
#
#
# Epoch: 23	100.00% complete. 169.84 seconds elapsed in epoch.
#
#
#
# Epoch: 23 	Training Loss: 0.9619 	Validation Loss: 3.1107
#
# 		Training Accuracy: 70.74%	 Validation Accuracy: 32.40%
#
#
#
# Epoch: 24	100.00% complete. 176.13 seconds elapsed in epoch.
#
#
#
# Epoch: 24 	Training Loss: 0.8833 	Validation Loss: 3.2915
#
# 		Training Accuracy: 72.98%	 Validation Accuracy: 31.86%
#
#
#
# Epoch: 25	100.00% complete. 171.65 seconds elapsed in epoch.
#
#
#
# Epoch: 25 	Training Loss: 0.7600 	Validation Loss: 3.0998
#
# 		Training Accuracy: 76.92%	 Validation Accuracy: 33.95%
#
#
#
# Epoch: 26	100.00% complete. 168.65 seconds elapsed in epoch.
#
#
#
# Epoch: 26 	Training Loss: 0.6860 	Validation Loss: 3.4368
#
# 		Training Accuracy: 78.71%	 Validation Accuracy: 32.50%
#
#
#
# Epoch: 27	100.00% complete. 171.55 seconds elapsed in epoch.
#
#
#
# Epoch: 27 	Training Loss: 0.6624 	Validation Loss: 3.3506
#
# 		Training Accuracy: 79.68%	 Validation Accuracy: 32.21%
#
#
#
# Epoch: 28	100.00% complete. 170.25 seconds elapsed in epoch.
#
#
#
# Epoch: 28 	Training Loss: 0.5844 	Validation Loss: 3.2976
#
# 		Training Accuracy: 81.90%	 Validation Accuracy: 34.94%
#
#
#
# Epoch: 29	100.00% complete. 172.51 seconds elapsed in epoch.
#
#
#
# Epoch: 29 	Training Loss: 0.5821 	Validation Loss: 3.2635
#
# 		Training Accuracy: 81.60%	 Validation Accuracy: 34.94%
#
#
#
# Epoch: 30	100.00% complete. 173.38 seconds elapsed in epoch.
#
#
#
# Epoch: 30 	Training Loss: 0.5194 	Validation Loss: 3.4950
#
# 		Training Accuracy: 83.94%	 Validation Accuracy: 34.69%
#
#
#
# Epoch: 31	100.00% complete. 170.54 seconds elapsed in epoch.
#
#
#
# Epoch: 31 	Training Loss: 0.4880 	Validation Loss: 3.5515
#
# 		Training Accuracy: 84.52%	 Validation Accuracy: 34.69%
#
#
#
# Epoch: 32	100.00% complete. 171.02 seconds elapsed in epoch.
#
#
#
# Epoch: 32 	Training Loss: 0.4754 	Validation Loss: 3.4128
#
# 		Training Accuracy: 84.91%	 Validation Accuracy: 35.94%
#
#
#
# Epoch: 33	100.00% complete. 170.72 seconds elapsed in epoch.
#
#
#
# Epoch: 33 	Training Loss: 0.3416 	Validation Loss: 3.4818
#
# 		Training Accuracy: 89.71%	 Validation Accuracy: 36.39%
#
#
#
# Epoch: 34	100.00% complete. 171.48 seconds elapsed in epoch.
#
#
#
# Epoch: 34 	Training Loss: 0.3135 	Validation Loss: 3.6736
#
# 		Training Accuracy: 90.49%	 Validation Accuracy: 37.18%
#
#
#
# Epoch: 35	100.00% complete. 171.98 seconds elapsed in epoch.
#
#
#
# Epoch: 35 	Training Loss: 0.2811 	Validation Loss: 3.8650
#
# 		Training Accuracy: 91.39%	 Validation Accuracy: 35.04%
#
#
#
# Epoch: 36	100.00% complete. 172.08 seconds elapsed in epoch.
#
#
#
# Epoch: 36 	Training Loss: 0.2906 	Validation Loss: 3.9547
#
# 		Training Accuracy: 91.02%	 Validation Accuracy: 34.54%
#
#
#
# Epoch: 37	100.00% complete. 174.88 seconds elapsed in epoch.
#
#
#
# Epoch: 37 	Training Loss: 0.3472 	Validation Loss: 3.7505
#
# 		Training Accuracy: 89.04%	 Validation Accuracy: 35.19%
#
#
#
# Epoch: 38	100.00% complete. 171.44 seconds elapsed in epoch.
#
#
#
# Epoch: 38 	Training Loss: 0.3644 	Validation Loss: 4.0176
#
# 		Training Accuracy: 88.35%	 Validation Accuracy: 34.84%
#
#
#
# Epoch: 39	100.00% complete. 168.80 seconds elapsed in epoch.
#
#
#
# Epoch: 39 	Training Loss: 0.3164 	Validation Loss: 3.7440
#
# 		Training Accuracy: 89.87%	 Validation Accuracy: 35.49%
#
#
#
# Epoch: 40	100.00% complete. 168.47 seconds elapsed in epoch.
#
#
#
# Epoch: 40 	Training Loss: 0.2823 	Validation Loss: 3.9249
#
# 		Training Accuracy: 91.13%	 Validation Accuracy: 34.79%
#
#
#
# Epoch: 41	100.00% complete. 170.99 seconds elapsed in epoch.
#
#
#
# Epoch: 41 	Training Loss: 0.2755 	Validation Loss: 4.0619
#
# 		Training Accuracy: 91.24%	 Validation Accuracy: 35.49%
#
#
#
# Epoch: 42	100.00% complete. 170.57 seconds elapsed in epoch.
#
#
#
# Epoch: 42 	Training Loss: 0.2515 	Validation Loss: 4.0250
#
# 		Training Accuracy: 92.02%	 Validation Accuracy: 35.89%
#
#
#
# Epoch: 43	100.00% complete. 167.70 seconds elapsed in epoch.
#
#
#
# Epoch: 43 	Training Loss: 0.2686 	Validation Loss: 4.1526
#
# 		Training Accuracy: 91.47%	 Validation Accuracy: 35.09%
#
#
#
# Epoch: 44	100.00% complete. 168.24 seconds elapsed in epoch.
#
#
#
# Epoch: 44 	Training Loss: 0.2904 	Validation Loss: 4.1972
#
# 		Training Accuracy: 90.88%	 Validation Accuracy: 34.49%
#
#
#
# Epoch: 45	100.00% complete. 169.10 seconds elapsed in epoch.
#
#
#
# Epoch: 45 	Training Loss: 0.2371 	Validation Loss: 4.0297
#
# 		Training Accuracy: 92.39%	 Validation Accuracy: 36.73%
#
#
#
# Epoch: 46	100.00% complete. 168.64 seconds elapsed in epoch.
#
#
#
# Epoch: 46 	Training Loss: 0.2010 	Validation Loss: 3.8645
#
# 		Training Accuracy: 93.64%	 Validation Accuracy: 38.23%
#
#
#
# Epoch: 47	100.00% complete. 171.73 seconds elapsed in epoch.
#
#
#
# Epoch: 47 	Training Loss: 0.2627 	Validation Loss: 4.3682
#
# 		Training Accuracy: 91.59%	 Validation Accuracy: 35.14%
#
#
#
# Epoch: 48	100.00% complete. 171.37 seconds elapsed in epoch.
#
#
#
# Epoch: 48 	Training Loss: 0.2665 	Validation Loss: 4.1179
#
# 		Training Accuracy: 91.38%	 Validation Accuracy: 35.04%
#
#
#
# Epoch: 49	100.00% complete. 173.06 seconds elapsed in epoch.
#
#
#
# Epoch: 49 	Training Loss: 0.1973 	Validation Loss: 4.1127
#
# 		Training Accuracy: 93.77%	 Validation Accuracy: 35.79%
#
#
#
# Epoch: 50	100.00% complete. 171.53 seconds elapsed in epoch.
#
#
#
# Epoch: 50 	Training Loss: 0.2223 	Validation Loss: 4.0756
#
# 		Training Accuracy: 92.92%	 Validation Accuracy: 36.83%
#
#
#
# Epoch: 51	100.00% complete. 171.09 seconds elapsed in epoch.
#
#
#
# Epoch: 51 	Training Loss: 0.1550 	Validation Loss: 4.3219
#
# 		Training Accuracy: 95.24%	 Validation Accuracy: 35.89%
#
#
#
# Epoch: 52	100.00% complete. 171.19 seconds elapsed in epoch.
#
#
#
# Epoch: 52 	Training Loss: 0.2440 	Validation Loss: 4.2772
#
# 		Training Accuracy: 92.24%	 Validation Accuracy: 36.98%
#
#
#
# Epoch: 53	100.00% complete. 174.52 seconds elapsed in epoch.
#
#
#
# Epoch: 53 	Training Loss: 0.1800 	Validation Loss: 4.2234
#
# 		Training Accuracy: 94.36%	 Validation Accuracy: 35.54%
#
#
#
# Epoch: 54	100.00% complete. 171.79 seconds elapsed in epoch.
#
#
#
# Epoch: 54 	Training Loss: 0.2203 	Validation Loss: 4.3236
#
# 		Training Accuracy: 92.90%	 Validation Accuracy: 34.99%
#
#
#
# Epoch: 55	100.00% complete. 169.61 seconds elapsed in epoch.
#
#
#
# Epoch: 55 	Training Loss: 0.2351 	Validation Loss: 4.3840
#
# 		Training Accuracy: 92.51%	 Validation Accuracy: 36.93%
#
#
#
# Epoch: 56	100.00% complete. 174.01 seconds elapsed in epoch.
#
#
#
# Epoch: 56 	Training Loss: 0.2070 	Validation Loss: 4.2084
#
# 		Training Accuracy: 93.34%	 Validation Accuracy: 38.03%
#
#
#
# Epoch: 57	100.00% complete. 171.70 seconds elapsed in epoch.
#
#
#
# Epoch: 57 	Training Loss: 0.1769 	Validation Loss: 4.3104
#
# 		Training Accuracy: 94.29%	 Validation Accuracy: 37.58%
#
#
#
# Epoch: 58	100.00% complete. 173.85 seconds elapsed in epoch.
#
#
#
# Epoch: 58 	Training Loss: 0.1606 	Validation Loss: 4.3043
#
# 		Training Accuracy: 94.91%	 Validation Accuracy: 37.63%
#
#
#
# Epoch: 59	100.00% complete. 171.69 seconds elapsed in epoch.
#
#
#
# Epoch: 59 	Training Loss: 0.1762 	Validation Loss: 4.2270
#
# 		Training Accuracy: 94.37%	 Validation Accuracy: 37.48%
#
#
#
# Epoch: 60	100.00% complete. 173.93 seconds elapsed in epoch.
#
#
#
# Epoch: 60 	Training Loss: 0.1284 	Validation Loss: 4.3104
#
# 		Training Accuracy: 96.06%	 Validation Accuracy: 37.03%
#
#
#
# Epoch: 61	100.00% complete. 173.23 seconds elapsed in epoch.
#
#
#
# Epoch: 61 	Training Loss: 0.1437 	Validation Loss: 4.2623
#
# 		Training Accuracy: 95.44%	 Validation Accuracy: 38.48%
#
#
#
# Epoch: 62	100.00% complete. 173.28 seconds elapsed in epoch.
#
#
#
# Epoch: 62 	Training Loss: 0.1497 	Validation Loss: 4.4868
#
# 		Training Accuracy: 95.38%	 Validation Accuracy: 37.33%
#
#
#
# Epoch: 63	100.00% complete. 171.80 seconds elapsed in epoch.
#
#
#
# Epoch: 63 	Training Loss: 0.1403 	Validation Loss: 4.4767
#
# 		Training Accuracy: 95.51%	 Validation Accuracy: 37.58%
#
#
#
# Epoch: 64	100.00% complete. 174.39 seconds elapsed in epoch.
#
#
#
# Epoch: 64 	Training Loss: 0.1317 	Validation Loss: 4.5624
#
# 		Training Accuracy: 95.93%	 Validation Accuracy: 36.34%
#
#
#
# Epoch: 65	100.00% complete. 172.42 seconds elapsed in epoch.
#
#
#
# Epoch: 65 	Training Loss: 0.1799 	Validation Loss: 4.8965
#
# 		Training Accuracy: 94.41%	 Validation Accuracy: 33.65%
#
#
#
# Epoch: 66	100.00% complete. 172.86 seconds elapsed in epoch.
#
#
#
# Epoch: 66 	Training Loss: 0.1758 	Validation Loss: 4.5983
#
# 		Training Accuracy: 94.37%	 Validation Accuracy: 36.98%
#
#
#
# Epoch: 67	100.00% complete. 171.98 seconds elapsed in epoch.
#
#
#
# Epoch: 67 	Training Loss: 0.1636 	Validation Loss: 4.4874
#
# 		Training Accuracy: 94.85%	 Validation Accuracy: 37.63%
#
#
#
# Epoch: 68	100.00% complete. 169.75 seconds elapsed in epoch.
#
#
#
# Epoch: 68 	Training Loss: 0.1229 	Validation Loss: 4.6064
#
# 		Training Accuracy: 96.22%	 Validation Accuracy: 38.83%
#
#
#
# Epoch: 69	100.00% complete. 170.39 seconds elapsed in epoch.
#
#
#
# Epoch: 69 	Training Loss: 0.1448 	Validation Loss: 4.5614
#
# 		Training Accuracy: 95.56%	 Validation Accuracy: 37.13%
#
#
#
# Epoch: 70	100.00% complete. 170.63 seconds elapsed in epoch.
#
#
#
# Epoch: 70 	Training Loss: 0.1757 	Validation Loss: 4.8238
#
# 		Training Accuracy: 94.43%	 Validation Accuracy: 34.59%
#
#
#
# Epoch: 71	100.00% complete. 169.92 seconds elapsed in epoch.
#
#
#
# Epoch: 71 	Training Loss: 0.1522 	Validation Loss: 4.6625
#
# 		Training Accuracy: 95.12%	 Validation Accuracy: 36.64%
#
#
#
# Epoch: 72	100.00% complete. 169.65 seconds elapsed in epoch.
#
#
#
# Epoch: 72 	Training Loss: 0.1844 	Validation Loss: 4.8143
#
# 		Training Accuracy: 94.20%	 Validation Accuracy: 35.14%
#
#
#
# Epoch: 73	100.00% complete. 170.76 seconds elapsed in epoch.
#
#
#
# Epoch: 73 	Training Loss: 0.1867 	Validation Loss: 4.6171
#
# 		Training Accuracy: 94.03%	 Validation Accuracy: 35.94%
#
#
#
# Epoch: 74	100.00% complete. 170.89 seconds elapsed in epoch.
#
#
#
# Epoch: 74 	Training Loss: 0.1554 	Validation Loss: 4.5636
#
# 		Training Accuracy: 94.88%	 Validation Accuracy: 35.59%
#
#
#
# Epoch: 75	100.00% complete. 170.64 seconds elapsed in epoch.
#
#
#
# Epoch: 75 	Training Loss: 0.1384 	Validation Loss: 4.4829
#
# 		Training Accuracy: 95.63%	 Validation Accuracy: 37.08%
#
#
#
# Epoch: 76	100.00% complete. 171.13 seconds elapsed in epoch.
#
#
#
# Epoch: 76 	Training Loss: 0.1956 	Validation Loss: 4.7387
#
# 		Training Accuracy: 93.55%	 Validation Accuracy: 35.79%
#
#
#
# Epoch: 77	100.00% complete. 172.82 seconds elapsed in epoch.
#
#
#
# Epoch: 77 	Training Loss: 0.1536 	Validation Loss: 4.3784
#
# 		Training Accuracy: 95.08%	 Validation Accuracy: 37.63%
#
#
#
# Epoch: 78	100.00% complete. 171.29 seconds elapsed in epoch.
#
#
#
# Epoch: 78 	Training Loss: 0.1591 	Validation Loss: 4.6740
#
# 		Training Accuracy: 94.71%	 Validation Accuracy: 36.88%
#
#
#
# Epoch: 79	100.00% complete. 171.82 seconds elapsed in epoch.
#
#
#
# Epoch: 79 	Training Loss: 0.0991 	Validation Loss: 4.4193
#
# 		Training Accuracy: 96.98%	 Validation Accuracy: 38.63%
#
#
#
# Epoch: 80	100.00% complete. 172.29 seconds elapsed in epoch.
#
#
#
# Epoch: 80 	Training Loss: 0.0781 	Validation Loss: 4.5054
#
# 		Training Accuracy: 97.51%	 Validation Accuracy: 38.63%
#
#
#
# Epoch: 81	100.00% complete. 170.92 seconds elapsed in epoch.
#
#
#
# Epoch: 81 	Training Loss: 0.1371 	Validation Loss: 4.5870
#
# 		Training Accuracy: 95.67%	 Validation Accuracy: 36.14%
#
#
#
# Epoch: 82	100.00% complete. 167.56 seconds elapsed in epoch.
#
#
#
# Epoch: 82 	Training Loss: 0.1157 	Validation Loss: 4.5864
#
# 		Training Accuracy: 96.32%	 Validation Accuracy: 36.93%
#
#
#
# Epoch: 83	100.00% complete. 167.65 seconds elapsed in epoch.
#
#
#
# Epoch: 83 	Training Loss: 0.0814 	Validation Loss: 4.5570
#
# 		Training Accuracy: 97.33%	 Validation Accuracy: 37.33%
#
#
#
# Epoch: 84	100.00% complete. 168.15 seconds elapsed in epoch.
#
#
#
# Epoch: 84 	Training Loss: 0.0771 	Validation Loss: 4.7089
#
# 		Training Accuracy: 97.64%	 Validation Accuracy: 37.78%
#
#
#
# Epoch: 85	100.00% complete. 166.97 seconds elapsed in epoch.
#
#
#
# Epoch: 85 	Training Loss: 0.1161 	Validation Loss: 4.7760
#
# 		Training Accuracy: 96.29%	 Validation Accuracy: 38.18%
#
#
#
# Epoch: 86	100.00% complete. 170.31 seconds elapsed in epoch.
#
#
#
# Epoch: 86 	Training Loss: 0.1561 	Validation Loss: 4.6439
#
# 		Training Accuracy: 94.99%	 Validation Accuracy: 39.07%
#
#
#
# Epoch: 87	100.00% complete. 170.06 seconds elapsed in epoch.
#
#
#
# Epoch: 87 	Training Loss: 0.1393 	Validation Loss: 4.7611
#
# 		Training Accuracy: 95.69%	 Validation Accuracy: 36.24%
#
#
#
# Epoch: 88	100.00% complete. 170.72 seconds elapsed in epoch.
#
#
#
# Epoch: 88 	Training Loss: 0.1723 	Validation Loss: 4.7207
#
# 		Training Accuracy: 94.59%	 Validation Accuracy: 38.63%
#
#
#
# Epoch: 89	100.00% complete. 171.16 seconds elapsed in epoch.
#
#
#
# Epoch: 89 	Training Loss: 0.1637 	Validation Loss: 4.9566
#
# 		Training Accuracy: 94.73%	 Validation Accuracy: 35.59%
#
#
#
# Epoch: 90	100.00% complete. 171.66 seconds elapsed in epoch.
#
#
#
# Epoch: 90 	Training Loss: 0.1157 	Validation Loss: 4.5571
#
# 		Training Accuracy: 96.15%	 Validation Accuracy: 37.28%
#
#
#
# Epoch: 91	100.00% complete. 172.95 seconds elapsed in epoch.
#
#
#
# Epoch: 91 	Training Loss: 0.1029 	Validation Loss: 4.6167
#
# 		Training Accuracy: 96.68%	 Validation Accuracy: 40.12%
#
#
#
# Epoch: 92	100.00% complete. 171.58 seconds elapsed in epoch.
#
#
#
# Epoch: 92 	Training Loss: 0.1014 	Validation Loss: 5.0192
#
# 		Training Accuracy: 96.77%	 Validation Accuracy: 36.14%
#
#
#
# Epoch: 93	100.00% complete. 171.04 seconds elapsed in epoch.
#
#
#
# Epoch: 93 	Training Loss: 0.1176 	Validation Loss: 4.6570
#
# 		Training Accuracy: 96.27%	 Validation Accuracy: 37.78%
#
#
#
# Epoch: 94	100.00% complete. 171.83 seconds elapsed in epoch.
#
#
#
# Epoch: 94 	Training Loss: 0.1340 	Validation Loss: 4.9310
#
# 		Training Accuracy: 95.78%	 Validation Accuracy: 35.79%
#
#
#
# Epoch: 95	100.00% complete. 170.44 seconds elapsed in epoch.
#
#
#
# Epoch: 95 	Training Loss: 0.1888 	Validation Loss: 5.1886
#
# 		Training Accuracy: 94.23%	 Validation Accuracy: 34.64%
#
#
#
# Epoch: 96	100.00% complete. 172.81 seconds elapsed in epoch.
#
#
#
# Epoch: 96 	Training Loss: 0.1742 	Validation Loss: 4.7402
#
# 		Training Accuracy: 94.35%	 Validation Accuracy: 37.68%
#
#
#
# Epoch: 97	100.00% complete. 170.58 seconds elapsed in epoch.
#
#
#
# Epoch: 97 	Training Loss: 0.1553 	Validation Loss: 4.6088
#
# 		Training Accuracy: 95.08%	 Validation Accuracy: 36.73%
#
#
#
# Epoch: 98	100.00% complete. 168.22 seconds elapsed in epoch.
#
#
#
# Epoch: 98 	Training Loss: 0.1098 	Validation Loss: 4.5669
#
# 		Training Accuracy: 96.57%	 Validation Accuracy: 38.23%
#
#
#
# Epoch: 99	100.00% complete. 173.38 seconds elapsed in epoch.
#
#
#
# Epoch: 99 	Training Loss: 0.0720 	Validation Loss: 4.7556
#
# 		Training Accuracy: 97.79%	 Validation Accuracy: 37.68%
#
#
#
# Epoch: 100	100.00% complete. 171.55 seconds elapsed in epoch.
#
#
#
# Epoch: 100 	Training Loss: 0.0635 	Validation Loss: 4.4468
#
# 		Training Accuracy: 97.98%	 Validation Accuracy: 39.67%
#
#
#
#
#
# Best epoch is epoch #22 with loss: 2.76 and acc: 39.67%
#
# 19074.88 total seconds elapsed. 192.68 seconds per epoch.

# %%
#models logs in detail over time of training.

history.index = [idx for idx in range(1, history.shape[0]+1)] #from first epoch
fig, axs = plt.subplots(1, 2, figsize = (10,5))
fig.suptitle('History Log',  size = 20)
#ethnicity model log

axs[0].plot(history["train_loss"], label = "train")
axs[0].plot(history["valid_loss"], label = "validation")
axs[0].set_xlabel("epochs")
axs[0].set_ylabel("loss")
axs[0].legend()
axs[0].set_title('Dog breed Classifier model loss')

axs[1].plot(history["train_acc"], label = "train")
axs[1].plot(history["valid_acc"], label = "validation")
axs[1].set_xlabel("epochs")
axs[1].set_ylabel("accuracy")
axs[1].legend()
axs[1].set_title('Dog breed Classifier accuracy')


plt.show()

# %%
def Accuracy_report(loader = None, model = None, n_classes = None):
    """
    Args:
    >loader (pytorch dataloader): the data for accuracy testing.
    >model (pytorch model) : the neural network.
    >n_classes (int): the number of classes.
    
    Output: 
    > class_acc (dict) : accuracy per classes. non existant taregts in the test set are set to nan value.
    > acc (float): overall accuracy.
    """
    my_classes = []

    classes = [n_class for n_class in range(n_classes)]
    correct_pred = {classname: 0 for classname in classes}
    total_pred = {classname: 0 for classname in classes}

    with torch.no_grad():
        for data in loader:
            inputs, targets = data 
            inputs = inputs.to(device)
            targets = targets.to(device)           
            outputs = model(inputs)    
            _, predictions = torch.max(outputs, 1)

            # collect the correct predictions for each class
            for target, prediction in zip(targets, predictions):
                if target == prediction:
                    correct_pred[classes[target]] += 1
                total_pred[classes[target]] += 1

    for classname, correct_count in correct_pred.items():
        try:
            accuracy = 100 * float(correct_count) / total_pred[classname]

            my_classes.append(accuracy)
        except ZeroDivisionError:
            my_classes.append(np.nan)
            continue
    
    acc =  round(100 * float(sum(correct_pred.values())/sum(total_pred.values())),2)
    class_acc = dict(zip(classes,[round(mc,2) for mc in my_classes]))
    return class_acc, acc

def test_report(class_acc,acc):
    """
    Args:
        > my_classes (dict) : accuracy per classes. non existant taregts in the test set are set to nan value.
        > acc (float): overall accuracy.
    
    Output:
        >report of test performance.
    """    
    print(f"{color_formats.BOLD + color_formats.UNDERLINE}Test Accuracy Report{color_formats.ENDC}")
    for key,value in class_acc.items():
        print(f"Class {trainset.classes[key]} has achived {color_formats.BOLD}{value}%{color_formats.ENDC} accuracy\n")
    print(f"Overall accuracy: {color_formats.BOLD}{acc}%{color_formats.ENDC}")

# %%
m1_test_class_acc, m1_test_acc = Accuracy_report(loader = testloader,model = model, n_classes = 120)
test_report(m1_test_class_acc,m1_test_acc)
# Out:
# Test Accuracy Report
#
# Class Afghan_hound has achived 54.17% accuracy
#
#
#
# Class African_hunting_dog has achived 60.0% accuracy
#
#
#
# Class Airedale has achived 68.29% accuracy
#
#
#
# Class American_Staffordshire_terrier has achived 17.65% accuracy
#
#
#
# Class Appenzeller has achived 9.68% accuracy
#
#
#
# Class Australian_terrier has achived 27.5% accuracy
#
#
#
# Class Bedlington_terrier has achived 56.76% accuracy
#
#
#
# Class Bernese_mountain_dog has achived 60.0% accuracy
#
#
#
# Class Blenheim_spaniel has achived 74.36% accuracy
#
#
#
# Class Border_collie has achived 26.67% accuracy
#
#
#
# Class Border_terrier has achived 54.29% accuracy
#
#
#
# Class Boston_bull has achived 29.73% accuracy
#
#
#
# Class Bouvier_des_Flandres has achived 16.67% accuracy
#
#
#
# Class Brabancon_griffon has achived 54.84% accuracy
#
#
#
# Class Brittany_spaniel has achived 32.26% accuracy
#
#
#
# Class Cardigan has achived 9.38% accuracy
#
#
#
# Class Chesapeake_Bay_retriever has achived 22.86% accuracy
#
#
#
# Class Chihuahua has achived 22.58% accuracy
#
#
#
# Class Dandie_Dinmont has achived 58.33% accuracy
#
#
#
# Class Doberman has achived 16.67% accuracy
#
#
#
# Class English_foxhound has achived 27.27% accuracy
#
#
#
# Class English_setter has achived 33.33% accuracy
#
#
#
# Class English_springer has achived 60.61% accuracy
#
#
#
# Class EntleBucher has achived 56.1% accuracy
#
#
#
# Class Eskimo_dog has achived 16.67% accuracy
#
#
#
# Class French_bulldog has achived 21.21% accuracy
#
#
#
# Class German_shepherd has achived 35.48% accuracy
#
#
#
# Class German_short-haired_pointer has achived 35.48% accuracy
#
#
#
# Class Gordon_setter has achived 35.48% accuracy
#
#
#
# Class Great_Dane has achived 6.25% accuracy
#
#
#
# Class Great_Pyrenees has achived 34.88% accuracy
#
#
#
# Class Greater_Swiss_Mountain_dog has achived 28.57% accuracy
#
#
#
# Class Ibizan_hound has achived 30.77% accuracy
#
#
#
# Class Irish_setter has achived 43.75% accuracy
#
#
#
# Class Irish_terrier has achived 42.86% accuracy
#
#
#
# Class Irish_water_spaniel has achived 60.0% accuracy
#
#
#
# Class Irish_wolfhound has achived 24.44% accuracy
#
#
#
# Class Italian_greyhound has achived 24.32% accuracy
#
#
#
# Class Japanese_spaniel has achived 68.42% accuracy
#
#
#
# Class Kerry_blue_terrier has achived 48.65% accuracy
#
#
#
# Class Labrador_retriever has achived 37.14% accuracy
#
#
#
# Class Lakeland_terrier has achived 39.02% accuracy
#
#
#
# Class Leonberg has achived 52.38% accuracy
#
#
#
# Class Lhasa has achived 39.47% accuracy
#
#
#
# Class Maltese_dog has achived 43.14% accuracy
#
#
#
# Class Mexican_hairless has achived 53.12% accuracy
#
#
#
# Class Newfoundland has achived 35.0% accuracy
#
#
#
# Class Norfolk_terrier has achived 31.43% accuracy
#
#
#
# Class Norwegian_elkhound has achived 55.0% accuracy
#
#
#
# Class Norwich_terrier has achived 47.37% accuracy
#
#
#
# Class Old_English_sheepdog has achived 48.57% accuracy
#
#
#
# Class Pekinese has achived 51.61% accuracy
#
#
#
# Class Pembroke has achived 54.05% accuracy
#
#
#
# Class Pomeranian has achived 53.33% accuracy
#
#
#
# Class Rhodesian_ridgeback has achived 25.71% accuracy
#
#
#
# Class Rottweiler has achived 61.29% accuracy
#
#
#
# Class Saint_Bernard has achived 67.65% accuracy
#
#
#
# Class Saluki has achived 25.0% accuracy
#
#
#
# Class Samoyed has achived 68.89% accuracy
#
#
#
# Class Scotch_terrier has achived 42.42% accuracy
#
#
#
# Class Scottish_deerhound has achived 59.57% accuracy
#
#
#
# Class Sealyham_terrier has achived 34.15% accuracy
#
#
#
# Class Shetland_sheepdog has achived 33.33% accuracy
#
#
#
# Class Shih-Tzu has achived 45.45% accuracy
#
#
#
# Class Siberian_husky has achived 23.08% accuracy
#
#
#
# Class Staffordshire_bullterrier has achived 28.12% accuracy
#
#
#
# Class Sussex_spaniel has achived 54.84% accuracy
#
#
#
# Class Tibetan_mastiff has achived 38.71% accuracy
#
#
#
# Class Tibetan_terrier has achived 35.71% accuracy
#
#
#
# Class Walker_hound has achived 38.71% accuracy
#
#
#
# Class Weimaraner has achived 53.12% accuracy
#
#
#
# Class Welsh_springer_spaniel has achived 36.67% accuracy
#
#
#
# Class West_Highland_white_terrier has achived 51.43% accuracy
#
#
#
# Class Yorkshire_terrier has achived 38.24% accuracy
#
#
#
# Class affenpinscher has achived 33.33% accuracy
#
#
#
# Class basenji has achived 44.19% accuracy
#
#
#
# Class basset has achived 38.89% accuracy
#
#
#
# Class beagle has achived 37.5% accuracy
#
#
#
# Class black-and-tan_coonhound has achived 51.52% accuracy
#
#
#
# Class bloodhound has achived 53.85% accuracy
#
#
#
# Class bluetick has achived 37.14% accuracy
#
#
#
# Class borzoi has achived 32.26% accuracy
#
#
#
# Class boxer has achived 19.35% accuracy
#
#
#
# Class briard has achived 32.26% accuracy
#
#
#
# Class bull_mastiff has achived 68.75% accuracy
#
#
#
# Class cairn has achived 17.07% accuracy
#
#
#
# Class chow has achived 57.5% accuracy
#
#
#
# Class clumber has achived 43.33% accuracy
#
#
#
# Class cocker_spaniel has achived 54.55% accuracy
#
#
#
# Class collie has achived 29.03% accuracy
#
#
#
# Class curly-coated_retriever has achived 38.71% accuracy
#
#
#
# Class dhole has achived 30.0% accuracy
#
#
#
# Class dingo has achived 25.0% accuracy
#
#
#
# Class flat-coated_retriever has achived 35.48% accuracy
#
#
#
# Class giant_schnauzer has achived 36.36% accuracy
#
#
#
# Class golden_retriever has achived 36.67% accuracy
#
#
#
# Class groenendael has achived 36.67% accuracy
#
#
#
# Class keeshond has achived 66.67% accuracy
#
#
#
# Class kelpie has achived 9.68% accuracy
#
#
#
# Class komondor has achived 78.12% accuracy
#
#
#
# Class kuvasz has achived 36.67% accuracy
#
#
#
# Class malamute has achived 27.03% accuracy
#
#
#
# Class malinois has achived 50.0% accuracy
#
#
#
# Class miniature_pinscher has achived 57.89% accuracy
#
#
#
# Class miniature_poodle has achived 15.62% accuracy
#
#
#
# Class miniature_schnauzer has achived 9.38% accuracy
#
#
#
# Class otterhound has achived 19.35% accuracy
#
#
#
# Class papillon has achived 52.5% accuracy
#
#
#
# Class pug has achived 40.0% accuracy
#
#
#
# Class redbone has achived 32.26% accuracy
#
#
#
# Class schipperke has achived 28.12% accuracy
#
#
#
# Class silky_terrier has achived 37.84% accuracy
#
#
#
# Class soft-coated_wheaten_terrier has achived 28.12% accuracy
#
#
#
# Class standard_poodle has achived 12.12% accuracy
#
#
#
# Class standard_schnauzer has achived 31.25% accuracy
#
#
#
# Class toy_poodle has achived 19.35% accuracy
#
#
#
# Class toy_terrier has achived 51.43% accuracy
#
#
#
# Class vizsla has achived 34.38% accuracy
#
#
#
# Class whippet has achived 20.51% accuracy
#
#
#
# Class wire-haired_fox_terrier has achived 33.33% accuracy
#
#
#
# Overall accuracy: 39.71%

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()
# get predictions
preds = np.squeeze(model(images.cuda()).data.max(1, keepdim=True)[1].cpu().numpy())
images = images.cpu().numpy()

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(int(batch_size/8)):
    ax = fig.add_subplot(2, int(batch_size/16), idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx].transpose(1,2,0)), cmap='gray')
    ax.set_title("Predicted : {}\n Actual : {}".format(trainset.classes[preds[idx]], trainset.classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx] else "red"))
plt.tight_layout()

# %%
import requests
from io import BytesIO
url = "https://cdn.britannica.com/73/234473-050-5BAFEBF0/Maltese-dog.jpg"
response = requests.get(url)
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1067>

# %%
transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize(224),
    torchvision.transforms.Resize(256),
    torchvision.transforms.CenterCrop(224),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.RandomHorizontalFlip(p = 0.5)
])


def predictor(img, n=5):
    """
    Args: 
        >img - the image to predict.
        >n - number of top probabilities.
    
    Outputs:
        >pred - the top prediction.
        > top preds - top n predictions.
    """
    #transform the image
    img = transforms(img)
    # get the class predicted 
    pred = int(np.squeeze(model(img.unsqueeze(0).cuda()).data.max(1, keepdim=True)[1].cpu().numpy()))
    # the number is also the index for the class label
    pred = trainset.classes[pred]
    # get model log probabilities
    preds = torch.from_numpy(np.squeeze(model(img.unsqueeze(0).cuda()).data.cpu().numpy()))
    # convert to prediction probabilities of the top n predictions
    top_preds = torch.topk(torch.exp(preds),n)
    #display at an orgenized fasion
    top_preds = dict(zip([trainset.classes[i] for i in top_preds.indices],[f"{round(float(i)*100,2)}%" for i in top_preds.values]))
    return pred, top_preds

# %%
my_prediction, top_predictions = predictor(img, n=5)
print(my_prediction)
# Out:
# Maltese_dog

# %%
torch.save(model,"mobilenetv2_dog_scratch.pb")

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

y_pred = []
y_true = []


# iterate over test data
for images, labels in testloader:
        output = np.squeeze(model(images.cuda()).data.max(1, keepdim=True)[1].cpu().numpy())
        y_pred.extend(output) # Save Prediction
        
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth

# constant for classes
classes = trainset.classes

# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix) *10, index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True)
plt.savefig('./confusion_mobilenetv2.png')

# %%
from sklearn.metrics import accuracy_score, classification_report

# print accuracy
print("Overall Accuracy: ", round(accuracy_score(y_true, y_pred)*100,2)," %")

# print precision, recall, F1-score per each class/tag
print(classification_report(y_true, y_pred,target_names=trainset.classes))
# Out:
# Overall Accuracy:  39.57  %
#
#                                 precision    recall  f1-score   support
#
#
#
#                   Afghan_hound       0.40      0.56      0.47        48
#
#            African_hunting_dog       0.50      0.54      0.52        35
#
#                       Airedale       0.33      0.61      0.43        41
#
# American_Staffordshire_terrier       0.19      0.15      0.17        34
#
#                    Appenzeller       0.11      0.10      0.10        31
#
#             Australian_terrier       0.42      0.35      0.38        40
#
#             Bedlington_terrier       0.38      0.57      0.46        37
#
#           Bernese_mountain_dog       0.44      0.60      0.51        45
#
#               Blenheim_spaniel       0.68      0.77      0.72        39
#
#                  Border_collie       0.32      0.27      0.29        30
#
#                 Border_terrier       0.73      0.46      0.56        35
#
#                    Boston_bull       0.39      0.30      0.34        37
#
#           Bouvier_des_Flandres       0.47      0.23      0.31        30
#
#              Brabancon_griffon       0.52      0.52      0.52        31
#
#               Brittany_spaniel       0.38      0.35      0.37        31
#
#                       Cardigan       0.14      0.09      0.11        32
#
#       Chesapeake_Bay_retriever       0.17      0.14      0.16        35
#
#                      Chihuahua       0.24      0.23      0.23        31
#
#                 Dandie_Dinmont       0.56      0.61      0.59        36
#
#                       Doberman       0.38      0.27      0.31        30
#
#               English_foxhound       0.41      0.21      0.28        33
#
#                 English_setter       0.21      0.24      0.22        33
#
#               English_springer       0.48      0.64      0.55        33
#
#                    EntleBucher       0.61      0.56      0.58        41
#
#                     Eskimo_dog       0.19      0.17      0.18        30
#
#                 French_bulldog       0.33      0.21      0.26        33
#
#                German_shepherd       0.60      0.39      0.47        31
#
#    German_short-haired_pointer       0.34      0.35      0.35        31
#
#                  Gordon_setter       0.32      0.39      0.35        31
#
#                     Great_Dane       0.18      0.16      0.17        32
#
#                 Great_Pyrenees       0.30      0.33      0.31        43
#
#     Greater_Swiss_Mountain_dog       0.43      0.34      0.38        35
#
#                   Ibizan_hound       0.52      0.36      0.42        39
#
#                   Irish_setter       0.83      0.47      0.60        32
#
#                  Irish_terrier       0.36      0.46      0.41        35
#
#            Irish_water_spaniel       0.37      0.57      0.45        30
#
#                Irish_wolfhound       0.27      0.22      0.24        45
#
#              Italian_greyhound       0.31      0.27      0.29        37
#
#               Japanese_spaniel       0.60      0.74      0.66        38
#
#             Kerry_blue_terrier       0.51      0.54      0.53        37
#
#             Labrador_retriever       0.33      0.37      0.35        35
#
#               Lakeland_terrier       0.28      0.39      0.32        41
#
#                       Leonberg       0.60      0.50      0.55        42
#
#                          Lhasa       0.46      0.34      0.39        38
#
#                    Maltese_dog       0.47      0.41      0.44        51
#
#               Mexican_hairless       0.57      0.53      0.55        32
#
#                   Newfoundland       0.26      0.35      0.30        40
#
#                Norfolk_terrier       0.36      0.34      0.35        35
#
#             Norwegian_elkhound       0.45      0.62      0.52        40
#
#                Norwich_terrier       0.35      0.39      0.37        38
#
#           Old_English_sheepdog       0.58      0.54      0.56        35
#
#                       Pekinese       0.43      0.48      0.45        31
#
#                       Pembroke       0.41      0.51      0.46        37
#
#                     Pomeranian       0.68      0.47      0.55        45
#
#            Rhodesian_ridgeback       0.17      0.23      0.19        35
#
#                     Rottweiler       0.44      0.58      0.50        31
#
#                  Saint_Bernard       0.88      0.65      0.75        34
#
#                         Saluki       0.29      0.17      0.22        40
#
#                        Samoyed       0.35      0.67      0.46        45
#
#                 Scotch_terrier       0.29      0.42      0.35        33
#
#             Scottish_deerhound       0.43      0.62      0.51        47
#
#               Sealyham_terrier       0.52      0.37      0.43        41
#
#              Shetland_sheepdog       0.32      0.27      0.30        33
#
#                       Shih-Tzu       0.44      0.39      0.41        44
#
#                 Siberian_husky       0.27      0.28      0.28        39
#
#      Staffordshire_bullterrier       0.27      0.25      0.26        32
#
#                 Sussex_spaniel       0.54      0.42      0.47        31
#
#                Tibetan_mastiff       0.33      0.32      0.33        31
#
#                Tibetan_terrier       0.41      0.29      0.34        42
#
#                   Walker_hound       0.29      0.39      0.33        31
#
#                     Weimaraner       0.43      0.47      0.45        32
#
#         Welsh_springer_spaniel       0.37      0.37      0.37        30
#
#    West_Highland_white_terrier       0.40      0.49      0.44        35
#
#              Yorkshire_terrier       0.33      0.41      0.37        34
#
#                  affenpinscher       0.35      0.37      0.36        30
#
#                        basenji       0.46      0.44      0.45        43
#
#                         basset       0.56      0.39      0.46        36
#
#                         beagle       0.43      0.45      0.44        40
#
#        black-and-tan_coonhound       0.56      0.45      0.50        33
#
#                     bloodhound       0.41      0.59      0.48        39
#
#                       bluetick       0.40      0.34      0.37        35
#
#                         borzoi       0.26      0.35      0.30        31
#
#                          boxer       0.33      0.26      0.29        31
#
#                         briard       0.48      0.45      0.47        31
#
#                   bull_mastiff       0.37      0.62      0.47        32
#
#                          cairn       0.48      0.24      0.32        41
#
#                           chow       0.41      0.57      0.48        40
#
#                        clumber       0.47      0.47      0.47        30
#
#                 cocker_spaniel       0.27      0.48      0.34        33
#
#                         collie       0.36      0.29      0.32        31
#
#         curly-coated_retriever       0.52      0.39      0.44        31
#
#                          dhole       0.31      0.33      0.32        30
#
#                          dingo       0.45      0.28      0.35        32
#
#          flat-coated_retriever       0.43      0.29      0.35        31
#
#                giant_schnauzer       0.26      0.27      0.26        33
#
#               golden_retriever       0.44      0.40      0.42        30
#
#                    groenendael       0.55      0.53      0.54        30
#
#                       keeshond       0.47      0.64      0.54        33
#
#                         kelpie       0.14      0.16      0.15        31
#
#                       komondor       0.56      0.78      0.65        32
#
#                         kuvasz       0.41      0.37      0.39        30
#
#                       malamute       0.30      0.30      0.30        37
#
#                       malinois       0.45      0.43      0.44        30
#
#             miniature_pinscher       0.39      0.58      0.46        38
#
#               miniature_poodle       0.22      0.19      0.20        32
#
#            miniature_schnauzer       0.26      0.16      0.20        32
#
#                     otterhound       0.50      0.19      0.28        31
#
#                       papillon       0.72      0.53      0.61        40
#
#                            pug       0.52      0.38      0.43        40
#
#                        redbone       0.26      0.35      0.30        31
#
#                     schipperke       0.46      0.34      0.39        32
#
#                  silky_terrier       0.46      0.30      0.36        37
#
#    soft-coated_wheaten_terrier       0.55      0.38      0.44        32
#
#                standard_poodle       0.12      0.09      0.11        33
#
#             standard_schnauzer       0.41      0.28      0.33        32
#
#                     toy_poodle       0.15      0.19      0.17        31
#
#                    toy_terrier       0.62      0.51      0.56        35
#
#                         vizsla       0.38      0.34      0.36        32
#
#                        whippet       0.12      0.10      0.11        39
#
#        wire-haired_fox_terrier       0.46      0.33      0.39        33
#
#
#
#                       accuracy                           0.40      4213
#
#                      macro avg       0.40      0.39      0.39      4213
#
#                   weighted avg       0.41      0.40      0.39      4213

# %%
from sklearn.metrics import roc_auc_score

def roc_auc_score_multiclass(actual_class, pred_class, average = "macro"):
    
    #creating a set of all the unique classes using the actual class list
    unique_class = set(actual_class)
    roc_auc_dict = {}
    for per_class in unique_class:
        
        #creating a list of all the classes except the current class 
        other_class = [x for x in unique_class if x != per_class]

        #marking the current class as 1 and all other classes as 0
        new_actual_class = [0 if x in other_class else 1 for x in actual_class]
        new_pred_class = [0 if x in other_class else 1 for x in pred_class]

        #using the sklearn metrics method to calculate the roc_auc_score
        roc_auc = roc_auc_score(new_actual_class, new_pred_class, average = average)
        roc_auc_dict[per_class] = roc_auc

    return roc_auc_dict

# %%
#ROC_AUC score
roc_auc_dict = roc_auc_score_multiclass(y_true, y_pred)
final_roc_auc_dictionary=dict(zip(list(trainset.classes) ,list(roc_auc_dict.values())) )
final_roc_auc_dictionary
# Out:
# {'Afghan_hound': 0.7764480792316927,
#  'African_hunting_dog': 0.7691547562059767,
#  'Airedale': 0.7988857189626547,
#  'American_Staffordshire_terrier': 0.5710168489506355,
#  'Appenzeller': 0.545517656315083,
#  'Australian_terrier': 0.6727234603402829,
#  'Bedlington_terrier': 0.7797129025577301,
#  'Bernese_mountain_dog': 0.7959213051823417,
#  'Blenheim_spaniel': 0.8829383362205594,
#  'Border_collie': 0.6313012989082795,
#  'Border_terrier': 0.7278533816590302,
#  'Boston_bull': 0.646613208035622,
#  'Bouvier_des_Flandres': 0.6157104151725237,
#  'Brabancon_griffon': 0.7562711158420883,
#  'Brittany_spaniel': 0.6752672744943768,
#  'Cardigan': 0.5446028163118871,
#  'Chesapeake_Bay_retriever': 0.5685563837789783,
#  'Chihuahua': 0.6102729053856004,
#  'Dandie_Dinmont': 0.8035206022397787,
#  'Doberman': 0.631779424655351,
#  'English_foxhound': 0.6048644338118023,
#  'English_setter': 0.6175039872408293,
#  'English_springer': 0.8154306220095694,
#  'EntleBucher': 0.7786901059326988,
#  'Eskimo_dog': 0.5807036417244402,
#  'French_bulldog': 0.6043859649122807,
#  'German_shepherd': 0.6925919069437374,
#  'German_short-haired_pointer': 0.674908594436988,
#  'Gordon_setter': 0.6905593866185341,
#  'Great_Dane': 0.5753744618512318,
#  'Great_Pyrenees': 0.6589537672187832,
#  'Greater_Swiss_Mountain_dog': 0.6695137796621761,
#  'Ibizan_hound': 0.6779299202634134,
#  'Irish_setter': 0.7340162341545086,
#  'Irish_terrier': 0.7252205429802366,
#  'Irish_water_spaniel': 0.7798669216670651,
#  'Irish_wolfhound': 0.6078721475794413,
#  'Italian_greyhound': 0.6325010355182769,
#  'Japanese_spaniel': 0.8661456035297826,
#  'Kerry_blue_terrier': 0.767995366055711,
#  'Labrador_retriever': 0.6826027490938932,
#  'Lakeland_terrier': 0.6900883941725323,
#  'Leonberg': 0.7483217453847997,
#  'Lhasa': 0.6692562243933186,
#  'Maltese_dog': 0.7029991237244537,
#  'Mexican_hairless': 0.7640703480028701,
#  'Newfoundland': 0.6703271028037383,
#  'Norfolk_terrier': 0.6689154072351775,
#  'Norwegian_elkhound': 0.8087856458183561,
#  'Norwich_terrier': 0.694015127639458,
#  'Old_English_sheepdog': 0.7697531286329753,
#  'Pekinese': 0.7395442834883756,
#  'Pembroke': 0.7535239981360672,
#  'Pomeranian': 0.7321337172104927,
#  'Rhodesian_ridgeback': 0.6094987348697258,
#  'Rottweiler': 0.7875727002051803,
#  'Saint_Bernard': 0.8231704742198386,
#  'Saluki': 0.5854630960939373,
#  'Samoyed': 0.8266154830454254,
#  'Scotch_terrier': 0.7080542264752793,
#  'Scottish_deerhound': 0.8039499085811177,
#  'Sealyham_terrier': 0.6812489769192993,
#  'Shetland_sheepdog': 0.634090909090909,
#  'Shih-Tzu': 0.6905432957543776,
#  'Siberian_husky': 0.6374319658938729,
#  'Staffordshire_bullterrier': 0.6223690504663957,
#  'Sussex_spaniel': 0.7083622591444131,
#  'Tibetan_mastiff': 0.658899122198053,
#  'Tibetan_terrier': 0.6408192622529711,
#  'Walker_hound': 0.6899615865228861,
#  'Weimaraner': 0.7319832276967232,
#  'Welsh_springer_spaniel': 0.6810622360347438,
#  'West_Highland_white_terrier': 0.7397456062367503,
#  'Yorkshire_terrier': 0.7025322691890826,
#  'affenpinscher': 0.680942704597976,
#  'basenji': 0.7182923428698901,
#  'basset': 0.6931277099460005,
#  'beagle': 0.7221243709561466,
#  'black-and-tan_coonhound': 0.7258373205741627,
#  'bloodhound': 0.79091875222685,
#  'bluetick': 0.6692744306913767,
#  'borzoi': 0.6735934342265624,
#  'boxer': 0.6271192977584426,
#  'briard': 0.7240130513259593,
#  'bull_mastiff': 0.8084339870844295,
#  'cairn': 0.6206329069522718,
#  'chow': 0.7835460100647017,
#  'clumber': 0.7314208303450475,
#  'cocker_spaniel': 0.7371610845295056,
#  'collie': 0.643248330016507,
#  'curly-coated_retriever': 0.6922332268863486,
#  'dhole': 0.6640369750577735,
#  'dingo': 0.6393095252331978,
#  'flat-coated_retriever': 0.6437265700930254,
#  'giant_schnauzer': 0.6332535885167464,
#  'golden_retriever': 0.6982070284484819,
#  'groenendael': 0.7651127579886843,
#  'keeshond': 0.8153110047846889,
#  'kelpie': 0.5770583607164346,
#  'komondor': 0.8882332276967232,
#  'kuvasz': 0.6814208303450474,
#  'malamute': 0.6455356218287254,
#  'malinois': 0.7147541636783807,
#  'miniature_pinscher': 0.7852820674440593,
#  'miniature_poodle': 0.5912386390815595,
#  'miniature_schnauzer': 0.5764507593877063,
#  'otterhound': 0.5960568334336095,
#  'papillon': 0.7615414569853822,
#  'pug': 0.6858225497244189,
#  'redbone': 0.6737129942456921,
#  'schipperke': 0.6703203480028701,
#  'silky_terrier': 0.647092135238687,
#  'soft-coated_wheaten_terrier': 0.6863041138483617,
#  'standard_poodle': 0.5429425837320574,
#  'standard_schnauzer': 0.6390703480028701,
#  'toy_poodle': 0.5927091528979805,
#  'toy_terrier': 0.7558264378034603,
#  'vizsla': 0.6697224049270509,
#  'whippet': 0.5479279544924011,
#  'wire-haired_fox_terrier': 0.6651116427432217}
